# %%
import requests
import matplotlib.pyplot as plt
def getGithubUserRepos( uname ):
    return f'https://api.github.com/users/{uname}/repos'

# %%
myUsername = "bitwyre"
myGithubUserRepoRequest = getGithubUserRepos(myUsername)

# %%
# TODO: Overcome low rate limit using authentication, ref: https://docs.github.com/en/apps/creating-github-apps/creating-github-apps/rate-limits-for-github-apps
response = requests.get(myGithubUserRepoRequest)

# %%
# TODO: Handle response error (using try catch)
def getLangsStat(response, ignoreForks=True):
    langs = {}
    if(response.status_code == 200):
        print("success!")
        print(response.json())
        for item in response.json():
            langResponse = requests.get(item['languages_url']);
            isForked = item['fork'];
            if(langResponse.status_code == 200):
                if(not(ignoreForks and isForked)):
                    print(langs)
                    A = langs
                    B = langResponse.json()
                    c = {x: A.get(x, 0) + B.get(x, 0) for x in set(A).union(B)}
                    langs = c
    else:
        # TODO: response error
        print("failed with status code: ", response.status_code)
        print(response.reason)
    return langs

# %%
langs = getLangsStat(response, ignoreForks=False)

sortedLangsRev = dict(sorted(langs.items(), key = lambda x: x[1], reverse=True))
# Out:
# success!
# [{'id': 252208122, 'node_id': 'MDEwOlJlcG9zaXRvcnkyNTIyMDgxMjI=', 'name': 'abseil-cpp', 'full_name': 'bitwyre/abseil-cpp', 'private': False, 'owner': {'login': 'bitwyre', 'id': 7370146, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjczNzAxNDY=', 'avatar_url': 'https://avatars.githubusercontent.com/u/7370146?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/bitwyre', 'html_url': 'https://github.com/bitwyre', 'followers_url': 'https://api.github.com/users/bitwyre/followers', 'following_url': 'https://api.github.com/users/bitwyre/following{/other_user}', 'gists_url': 'https://api.github.com/users/bitwyre/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/bitwyre/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/bitwyre/subscriptions', 'organizations_url': 'https://api.github.com/users/bitwyre/orgs', 'repos_url': 'https://api.github.com/users/bitwyre/repos', 'events_url': 'https://api.github.com/users/bitwyre/events{/privacy}', 'received_events_url': 'https://api.github.com/users/bitwyre/received_events', 'type': 'Organization', 'site_admin': False}, 'html_url': 'https://github.com/bitwyre/abseil-cpp', 'description': 'Abseil Common Libraries (C++)', 'fork': True, 'url': 'https://api.github.com/repos/bitwyre/abseil-cpp', 'forks_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/forks', 'keys_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/teams', 'hooks_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/hooks', 'issue_events_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/issues/events{/number}', 'events_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/events', 'assignees_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/assignees{/user}', 'branches_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/branches{/branch}', 'tags_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/tags', 'blobs_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/languages', 'stargazers_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/stargazers', 'contributors_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/contributors', 'subscribers_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/subscribers', 'subscription_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/subscription', 'commits_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/contents/{+path}', 'compare_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/merges', 'archive_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/downloads', 'issues_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/issues{/number}', 'pulls_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/bitwyre/abseil-cpp/notifications{?since,all,participating} ...
# {}
# {'C++': 6584649, 'CMake': 138094, 'Shell': 35802, 'C': 53479, 'Starlark': 156664, 'NASL': 118169, 'Python': 18694}
# {'C++': 6647670, 'CMake': 138547, 'Shell': 35802, 'C': 53479, 'Starlark': 156664, 'NASL': 118169, 'Python': 18694}
# {'C++': 6647670, 'CMake': 138547, 'Shell': 35802, 'Ruby': 3772, 'C': 53479, 'Starlark': 156664, 'NASL': 118169, 'Python': 18694, 'Dockerfile': 1971}
# {'C++': 6647670, 'CMake': 138547, 'Shell': 35802, 'Ruby': 3772, 'C': 53479, 'Starlark': 156664, 'NASL': 118169, 'Python': 18694, 'Dockerfile': 1971}
# {'CMake': 191728, 'Roff': 147365, 'Awk': 1180, 'Perl': 3687, 'Batchfile': 527, 'M4': 351134, 'Python': 18694, 'C++': 8872837, 'Ruby': 3772, 'Shell': 63486, 'Makefile': 15744, 'C': 1122655, 'Starlark': 156664, 'NASL': 118169, 'Dockerfile': 1971}
# {'CMake': 278259, 'Roff': 150377, 'Awk': 1180, 'Perl': 3687, 'Batchfile': 2088, 'M4': 351134, 'Objective-C': 1592, 'PowerShell': 1020, 'Python': 79412, 'C++': 10450160, 'Ruby': 3772, 'Shell': 64557, 'Makefile': 15744, 'Objective-C++': 6690, 'C': 1128083, 'Starlark': 156664, 'NASL': 118169, 'Dockerfile': 1971}
# {'CMake': 278259, 'Roff': 150377, 'Awk': 1180, 'Perl': 3687, 'Batchfile': 2088, 'M4': 351134, 'PHP': 6088357, 'Objective-C': 1592, 'PowerShell': 1020, 'Python': 5781901, 'C++': 10450160, 'Ruby': 3772, 'Shell': 66933, 'Makefile': 15744, 'Objective-C++': 6690, 'JavaScript': 6595317, 'C': 1128083, 'Starlark': 156664, 'NASL': 118169, 'Dockerfile': 3614}
# {'CMake': 279177, 'Roff': 150377, 'Awk': 1180, 'Perl': 3687, 'Batchfile': 2088, 'M4': 351134, 'PHP': 6088357, 'Objective-C': 1592, 'PowerShell': 1020, 'Python': 5781901, 'C++': 10513907, 'Ruby': 3772, 'Shell': 66933, 'Makefile': 15744, 'Objective-C++': 6690, 'JavaScript': 6595317, 'C': 1145745, 'Starlark': 156664, 'NASL': 118169, 'Dockerfile': 3614}
# {'CMake': 279177, 'Roff': 150377, 'Awk': 1180, 'Perl': 3687, 'Batchfile': 2088, 'M4': 351134, 'PHP': 6088357, 'Objective-C': 1592, 'PowerShell': 1020, 'Python': 5781901, 'C++': 10513907, 'Ruby': 3772, 'Shell': 66933, 'Makefile': 15744, 'Objective-C++': 6690, 'JavaScript': 6671423, 'C': 1145745, 'Starlark': 156664, 'NASL': 118169, 'Dockerfile': 3614}
# {'CMake': 279177, 'Roff': 150377, 'Awk': 1180, 'Perl': 3687, 'Batchfile': 2088, 'M4': 351134, 'PHP': 6088357, 'Objective-C': 1592, 'PowerShell': 1020, 'Python': 5781901, 'C++': 10513907, 'Ruby': 3772, 'Shell': 66933, 'Makefile': 15744, 'Objective-C++': 6690, 'JavaScript': 11263879, 'C': 1145745, 'Starlark': 156664, 'NASL': 118169, 'Dockerfile': 3614}
# {'CMake': 287829, 'Roff': 150377, 'Awk': 1180, 'TeX': 36165, 'Perl': 3687, 'Batchfile': 2088, 'M4': 351134, 'PHP': 6088357, 'Objective-C': 1592, 'PowerShell': 1020, 'Python': 5787616, 'CSS': 32420, 'C++': 11014602, 'Ruby': 3772, 'Shell': 67094, 'Makefile': 15744, 'Objective-C++': 6690, 'JavaScript': 11295548, 'C': 1145745, 'HTML': 41017, 'Starlark': 156664, 'NASL': 118169, 'Dockerfile': 3614}
# {'CMake': 287829, 'Roff': 150377, 'Awk': 1180, 'TeX': 36165, 'Perl': 3687, 'Batchfile': 2088, 'M4': 351134, 'PHP': 6088357, 'Objective-C': 1592, 'PowerShell': 1020, 'Python': 5787616, 'CSS': 32420, 'C++': 11014602, 'Ruby': 3772, 'Shell': 67639, 'Makefile': 15744, 'Objective-C++': 6690, 'JavaScript': 11295548, 'C': 1145745, 'Starlark': 156664, 'NASL': 118169, 'Dockerfile': 5325, 'HTML': 41017}
# {'CMake': 287829, 'Roff': 150377, 'Awk': 1180, 'TeX': 36165, 'Perl': 3687, 'Batchfile': 2088, 'M4': 351134, 'PHP': 6088357, 'Objective-C': 1592, 'PowerShell': 1020, 'Python': 5787616, 'CSS': 32420, 'C++': 11014602, 'Ruby': 3772, 'Shell': 68164, 'Makefile': 15744, 'Objective-C++': 6690, 'JavaScript': 11295548, 'C': 1145745, 'HTML': 41017, 'Starlark': 156664, 'NASL': 118169, 'Dockerfile': 7095}
# {'CMake': 287829, 'Roff': 150377, 'Awk': 1180, 'TeX': 36165, 'Perl': 3687, 'Batchfile': 2088, 'M4': 351134, 'PHP': 6088357, 'Objective-C': 1592, 'PowerShell': 1020, 'Python': 5787616, 'CSS': 32420, 'C++': 11014602, 'Ruby': 3772, 'Shell': 68164, 'Makefile': 15744, 'Objective-C++': 6690, 'JavaScript': 11295548, 'C': 1145745, 'Starlark': 156664, 'NASL': 118169, 'Dockerfile': 7095, 'HTML': 41017}
# {'CMake': 287829, 'Roff': 150377, 'Awk': 1180, 'TeX': 36165, 'Perl': 3687, 'Batchfile': 2088, 'M4': 351134, 'PHP': 6088357, 'Objective-C': 1592, 'PowerShell': 1020, 'Python': 5787616, 'CSS': 32420, 'C++': 11014602, 'Ruby': 3772, 'Shell': 68164, 'Makefile': 15744, 'Objective-C++': 6690, 'JavaScript': 11295548, 'C': 1145745, 'HTML': 41017, 'Starlark': 156664, 'NASL': 118169, 'Dockerfile': 7095}
# {'CMake': 287829, 'Roff': 150377, 'Awk': 1180, 'TeX': 36165, 'Perl': 3687, 'Batchfile': 2088, 'M4': 351134, 'PHP': 6088357, 'Objective-C': 1592, 'PowerShell': 1020, 'Python': 5787616, 'CSS': 32420, 'C++': 11014602, 'Ruby': 3772, 'Shell': 68634, 'Makefile': 15744, 'Objective-C++': 6690, 'JavaScript': 11295548, 'C': 1145745, 'Starlark': 156664, 'NASL': 118169, 'Dockerfile': 8216, 'HTML': 41017}
# {'CMake': 287829, 'Roff': 150377, 'Awk': 1180, 'TeX': 36165, 'Perl': 3687, 'Batchfile': 2088, 'M4': 351134, 'PHP': 6088357, 'Objective-C': 1592, 'PowerShell': 1020, 'Python': 5787616, 'CSS': 32420, 'C++': 11014602, 'Ruby': 3772, 'Shell': 69172, 'Makefile': 15744, 'Objective-C++': 6690, 'JavaScript': 11295548, 'C': 1145745, 'HTML': 41017, 'Starlark': 156664, 'NASL': 118169, 'Dockerfile': 9816}
# {'CMake': 287829, 'Roff': 150377, 'Awk': 1180, 'TeX': 36165, 'Perl': 3687, 'Batchfile': 2088, 'M4': 351134, 'PHP': 6088357, 'Objective-C': 1592, 'PowerShell': 1020, 'Python': 5787616, 'CSS': 32420, 'C++': 11014602, 'Ruby': 3772, 'Shell': 69719, 'Makefile': 15744, 'Objective-C++': 6690, 'JavaScript': 11295548, 'C': 1145745, 'Starlark': 156664, 'NASL': 118169, 'Dockerfile': 11843, 'HTML': 41017}
# {'CMake': 295513, 'Roff': 150377, 'Awk': 1180, 'TeX': 36165, 'Perl': 3687, 'Batchfile': 2088, 'M4': 351134, 'PHP': 6088357, 'Objective-C': 1592, 'PowerShell': 1020, 'Python': 5787616, 'CSS': 32420, 'C++': 11463605, 'Ruby': 3772, 'Shell': 69719, 'Makefile': 15744, 'Objective-C++': 6690, 'JavaScript': 11295548, 'C': 1145745, 'HTML': 41017, 'Starlark': 156664, 'NASL': 118169, 'Dockerfile': 11843}
# {'CMake': 327920, 'Roff': 150377, 'Awk': 1180, 'TeX': 36165, 'Perl': 3687, 'Batchfile': 2088, 'M4': 351134, 'PHP': 6088357, 'Objective-C': 1592, 'PowerShell': 1020, 'Python': 5787616, 'CSS': 32420, 'C++': 12648293, 'Ruby': 3772, 'Shell': 73906, 'Makefile': 15744, 'Objective-C++': 6690, 'JavaScript': 11295548, 'C': 1146812, 'Starlark': 156664, 'NASL': 118169, 'Dockerfile': 12603, 'HTML': 41017}
# {'CMake': 327920, 'Roff': 150377, 'Awk': 1180, 'TeX': 36165, 'Perl': 3687, 'Batchfile': 2088, 'M4': 351134, 'PHP': 6088357, 'Objective-C': 1592, 'PowerShell': 1020, 'Python': 5787616, 'CSS': 32420, 'C++': 12648293, 'Ruby': 3772, 'Shell': 73906, 'Makefile': 15744, 'Objective-C++': 6690, 'JavaScript': 11295548, 'C': 1146812, 'HTML': 41017, 'Starlark': 156664, 'NASL': 118169, 'Dockerfile': 12603}
# {'CMake': 327920, 'Roff': 150377, 'Awk': 1180, 'TeX': 36165, 'Perl': 3687, 'Batchfile': 2088, 'M4': 351134, 'PHP': 6088357, 'Objective-C': 1592, 'PowerShell': 1020, 'Python': 5787616, 'CSS': 32420, 'C++': 12648293, 'Ruby': 3772, 'Shell': 73906, 'Makefile': 15744, 'Objective-C++': 6690, 'JavaScript': 11295548, 'C': 1146812, 'Starlark': 156664, 'NASL': 118169, 'Dockerfile': 13686, 'HTML': 41017}
# {'CMake': 327920, 'Roff': 150377, 'Awk': 1180, 'TeX': 36165, 'Perl': 3687, 'Batchfile': 2088, 'M4': 351134, 'PHP': 6088357, 'Objective-C': 1592, 'PowerShell': 1020, 'Python': 5787616, 'CSS': 32420, 'Rust': 393674, 'C++': 12648293, 'Ruby': 3772, 'Shell': 74848, 'Makefile': 15744, 'Objective-C++': 6690, 'JavaScript': 11295548, 'C': 1146812, 'HTML': 41017, 'Starlark': 156664, 'XSLT': 19049, 'NASL': 118169, 'Dockerfile': 13686}
# {'CMake': 327920, 'TypeScript': 43956, 'Roff': 150377, 'Awk': 1180, 'TeX': 36165, 'Perl': 3687, 'Batchfile': 2088, 'M4': 351134, 'PHP': 6088357, 'Objective-C': 1592, 'PowerShell': 1020, 'Python': 5787616, 'CSS': 32420, 'Rust': 393674, 'C++': 12648293, 'Ruby': 3772, 'Shell': 74848, 'Makefile': 15744, 'Objective-C++': 6690, 'JavaScript': 11313423, 'C': 1146812, 'Starlark': 156664, 'XSLT': 19049, 'NASL': 118169, 'Dockerfile': 13686, 'HTML': 41017}
# {'CMake': 330680, 'TypeScript': 43956, 'Roff': 150377, 'Awk': 1180, 'TeX': 36165, 'Perl': 3687, 'Batchfile': 2088, 'M4': 351134, 'PHP': 6088357, 'Objective-C': 1592, 'PowerShell': 1020, 'Python': 5787616, 'CSS': 32420, 'Rust': 393674, 'C++': 12672452, 'Ruby': 3772, 'Shell': 74848, 'Makefile': 15744, 'Objective-C++': 6690, 'JavaScript': 11313423, 'C': 1146812, 'HTML': 41017, 'Starlark': 156664, 'XSLT': 19049, 'NASL': 118169, 'Dockerfile': 13686}
# {'CMake': 363256, 'TypeScript': 43956, 'Roff': 150377, 'Awk': 1180, 'TeX': 36165, 'Perl': 3687, 'Cuda': 905, 'Batchfile': 2088, 'M4': 351134, 'PHP': 6088357, 'Objective-C': 1666, 'PowerShell': 1020, 'Python': 5829705, 'CSS': 32420, 'Rust': 393674, 'C++': 15175649, 'Ruby': 4342, 'Shell': 77616, 'Makefile': 16043, 'Objective-C++': 6690, 'JavaScript': 11313423, 'C': 1146812, 'Starlark': 156664, 'XSLT': 19049, 'NASL': 118169, 'Dockerfile': 13686, 'QMake': 901, 'HTML': 41500}
# {'CMake': 838526, 'Roff': 150377, 'TeX': 36165, 'Mako': 5629, 'C#': 2100715, 'PHP': 6564112, 'Objective-C': 697769, 'Python': 8979075, 'CSS': 33939, 'C++': 27010622, 'Ruby': 1106662, 'Go': 34794, 'Makefile': 1110485, 'TSQL': 4901, 'Starlark': 688955, 'XSLT': 28894, 'NASL': 118169, 'DTrace': 147, 'HTML': 41514, 'Java': 6259, 'TypeScript': 43956, 'Awk': 1180, 'Swift': 3516, 'Perl': 3687, 'Cuda': 905, 'Batchfile': 37625, 'M4': 415070, 'PowerShell': 4246, 'Rust': 393674, 'Shell': 584260, 'JavaScript': 11390238, 'Objective-C++': 84432, 'C': 4471876, 'QMake': 901, 'Dockerfile': 179140}
# {'CMake': 838526, 'Roff': 150377, 'TeX': 36165, 'Mako': 5629, 'C#': 2100715, 'PHP': 6564112, 'Objective-C': 697769, 'Python': 8983412, 'CSS': 33939, 'C++': 27010622, 'Ruby': 1106662, 'Go': 34794, 'Makefile': 1110485, 'TSQL': 4901, 'Starlark': 688955, 'XSLT': 28894, 'NASL': 118169, 'DTrace': 147, 'HTML': 41514, 'Java': 6259, 'TypeScript': 43956, 'Awk': 1180, 'Swift': 3516, 'Perl': 3687, 'Cuda': 905, 'Batchfile': 37625, 'M4': 415070, 'PowerShell': 4246, 'Rust': 393674, 'Shell': 584260, 'JavaScript': 11390238, 'Objective-C++': 84432, 'C': 4471876, 'QMake': 901, 'Dockerfile': 179140}
# {'CMake': 844190, 'Roff': 150377, 'TeX': 36165, 'Mako': 5629, 'C#': 2100715, 'PHP': 6564112, 'Objective-C': 697769, 'Python': 8983412, 'CSS': 33939, 'C++': 27014855, 'Ruby': 1106662, 'Go': 34794, 'Makefile': 1120859, 'TSQL': 4901, 'Starlark': 688955, 'XSLT': 28894, 'NASL': 118169, 'DTrace': 147, 'HTML': 41514, 'Java': 6259, 'TypeScript': 43956, 'Awk': 1180, 'Swift': 3516, 'Perl': 3687, 'Cuda': 905, 'Batchfile': 37625, 'M4': 415070, 'PowerShell': 4246, 'Rust': 393674, 'Shell': 586269, 'JavaScript': 11390238, 'Objective-C++': 84432, 'C': 4763282, 'QMake': 901, 'Dockerfile': 179140}

# %%
for lang in langs:
    print(lang.value)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_69181/1360760336.py in <module>
#       1 for lang in langs:
# ----> 2     print(lang.value)
#
# AttributeError: 'str' object has no attribute 'value'

# %%
print(sortedLangsRev)
# Out:
# {'C++': 27014855, 'JavaScript': 11390238, 'Python': 8983412, 'PHP': 6564112, 'C': 4763282, 'C#': 2100715, 'Makefile': 1120859, 'Ruby': 1106662, 'CMake': 844190, 'Objective-C': 697769, 'Starlark': 688955, 'Shell': 586269, 'M4': 415070, 'Rust': 393674, 'Dockerfile': 179140, 'Roff': 150377, 'NASL': 118169, 'Objective-C++': 84432, 'TypeScript': 43956, 'HTML': 41514, 'Batchfile': 37625, 'TeX': 36165, 'Go': 34794, 'CSS': 33939, 'XSLT': 28894, 'Java': 6259, 'Mako': 5629, 'TSQL': 4901, 'PowerShell': 4246, 'Perl': 3687, 'Swift': 3516, 'Awk': 1180, 'Cuda': 905, 'QMake': 901, 'DTrace': 147}

# %%
import json

# https://raw.githubusercontent.com/ozh/github-colors/master/colors.json
f = open('colors.json')

githubLangColors = json.load(f)

# %%
import random

def getRandomColor():
    color = "#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
    return color

# %%
langsLabels = list(sortedLangsRev.keys())
langsValues = list(sortedLangsRev.values())
langsColors = []
for lang in langsLabels:
    color = ''
    if lang in githubLangColors:
        color =githubLangColors[lang]['color']
        #print(f'{lang} {color}')
    else:
        color = langsColors.append(getRandomColor())
        #print(f'{lang} {color} (color not found, randomly assigned)')
    langsColors.append(color)
    
patches, text = plt.pie(langsValues, labels=langsLabels, radius=3.3, colors=langsColors)
plt.legend(patches, langsLabels, loc="best")
plt.show()

# %%
langsLabels[5]
# Out:
# 'C#'
